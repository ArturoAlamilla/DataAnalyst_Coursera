# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio
#
# **My name is Arturo Alamilla**
# I'm a CRM Admin

# %% [markdown]
# *I'm interesting in data science because i know is the future for data and professional growth*

# %% [markdown]
# ### This code is for the sum of one variable and another variable ###

# %%
a=1
b=2
c = a+b 
c
# Out:
# 3

# %% [markdown]
# This is the first line.
# And this is the second line.
# - One
# - Two
# - Three
#
# This is a guide on Markdown [Markdown][1].
#
# [1]: http://en.wikipedia.org/wiki/Markdown        "Markdown"
